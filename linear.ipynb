# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('EquationCitations.csv')

# %%
dataset
# Out:
#      Unnamed: 0 journal              authors  volume  startpage  pages  \
# 0             1   AmNat       Prodohl et al.     151          7     13
# 1             2   AmNat             Mauricio     151         20      9
# 2             3   AmNat        Thrall et al.     151         29     17
# 3             4   AmNat        Watson et al.     151         46     13
# 4             5   AmNat       Klein & Nelson     151         59      9
# ..          ...     ...                  ...     ...        ...    ...
# 644         645   ProcB        Kaar & Jokela     265       2415      6
# 645         646   ProcB      Bonabeau et al.     265       2421      5
# 646         647   ProcB  Kleinschmidt et al.     265       2427      7
# 647         648   ProcB    Willis & Anderson     265       2435      7
# 648         649   ProcB         Ghani et al.     265       2443     10
#
#      equations  mainequations  appequations  cites  selfcites  othercites  \
# ...

# %%
dataset.shape
# Out:
# (649, 14)

# %%
dataset.head()
# Out:
#    Unnamed: 0 journal         authors  volume  startpage  pages  equations  \
# 0           1   AmNat  Prodohl et al.     151          7     13          0
# 1           2   AmNat        Mauricio     151         20      9          2
# 2           3   AmNat   Thrall et al.     151         29     17         15
# 3           4   AmNat   Watson et al.     151         46     13          7
# 4           5   AmNat  Klein & Nelson     151         59      9          0
#
#    mainequations  appequations  cites  selfcites  othercites  theocites  \
# 0              0             0     37          4          33          8
# 1              2             0    178          5         173         19
# 2             15             0     25         10          15          8
# 3              7             0    127         11         116         17
# 4              0             0     43          8          35          5
#
#    nontheocites
# 0            22
# 1           150
# 2             6
# ...

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'journal', 'authors', 'volume', 'startpage', 'pages',
#        'equations', 'mainequations', 'appequations', 'cites', 'selfcites',
#        'othercites', 'theocites', 'nontheocites'],
#       dtype='object')

# %%
dataset =dataset.drop(['journal','authors'],axis=1)

# %%
dataset.head()
# Out:
#    Unnamed: 0  volume  startpage  pages  equations  mainequations  \
# 0           1     151          7     13          0              0
# 1           2     151         20      9          2              2
# 2           3     151         29     17         15             15
# 3           4     151         46     13          7              7
# 4           5     151         59      9          0              0
#
#    appequations  cites  selfcites  othercites  theocites  nontheocites
# 0             0     37          4          33          8            22
# 1             0    178          5         173         19           150
# 2             0     25         10          15          8             6
# 3             0    127         11         116         17            98
# 4             0     43          8          35          5            28

# %% [markdown]
# Segregate and shape the dataset

# %%
x=dataset.iloc[:,2].values.reshape(-1,1)

# %%
x.shape
# Out:
# (649, 1)

# %%
x
# Out:
# array([[   7],
#        [  20],
#        [  29],
#        [  46],
#        [  59],
#        [  68],
#        [  84],
#        [  97],
#        [ 116],
#        [ 135],
#        [ 148],
#        [ 157],
#        [ 174],
#        [ 193],
#        [ 207],
#        [ 223],
#        [ 236],
#        [ 243],
#        [ 256],
#        [ 264],
#        [ 277],
#        [ 283],
#        [ 293],
#        [ 311],
#        [ 327],
#        [ 343],
#        [ 356],
#        [ 367],
#        [ 383],
#        [ 392],
#        [ 397],
#        [ 409],
#        [ 425],
#        [ 441],
#        [ 451],
#        [ 465],
#        [ 477],
#        [ 487],
#        [ 497],
#        [ 514],
#        [ 530],
#        [ 538],
#        [ 545],
#        [ 564],
#        [ 570],
#        [ 578],
#        [ 587],
#        [   1],
#        [   7],
#        [  24],
#        [  45],
#        [  59],
#        [  71],
#        [  82],
#        [ 102],
#        [ 114],
#        [ 129],
#        [ 145],
# ...

# %%
y=dataset.iloc[:,-1].values.reshape(-1,1)

# %%
y.shape
# Out:
# (649, 1)

# %%
y
# Out:
# array([[ 22],
#        [150],
#        [  6],
#        [ 98],
#        [ 28],
#        [ 61],
#        [  6],
#        [ 20],
#        [  4],
#        [  8],
#        [ 30],
#        [ 36],
#        [126],
#        [ 16],
#        [ 26],
#        [ 61],
#        [ 46],
#        [ 25],
#        [ 11],
#        [144],
#        [102],
#        [ 43],
#        [ 33],
#        [ 80],
#        [100],
#        [ 14],
#        [ 17],
#        [  5],
#        [ 21],
#        [ 24],
#        [ 22],
#        [ 12],
#        [ 11],
#        [  6],
#        [ 55],
#        [ 37],
#        [ 29],
#        [157],
#        [ 18],
#        [ 46],
#        [ 27],
#        [  7],
#        [ 28],
#        [  7],
#        [  7],
#        [ 12],
#        [  0],
#        [ 59],
#        [ 41],
#        [ 85],
#        [  6],
#        [ 25],
#        [  4],
#        [ 38],
#        [  3],
#        [ 14],
#        [ 14],
#        [  8],
#        [ 20],
#        [  1],
#        [  6],
#        [ 18],
# ...

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Divide the dataset into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (519, 1)

# %%
x_test.shape
# Out:
# (130, 1)

# %%
y_test.shape
# Out:
# (130, 1)

# %%
y_train.shape
# Out:
# (519, 1)

# %% [markdown]
# perform linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=lm.predict(x_test)

# %%
y_pred
# Out:
# array([[32.00742392],
#        [33.88658785],
#        [31.59467898],
#        [30.88663686],
#        [32.61479654],
#        [32.73224429],
#        [31.61649071],
#        [32.67687607],
#        [31.98393437],
#        [33.94195607],
#        [32.65506434],
#        [33.7758514 ],
#        [34.00571342],
#        [32.68526519],
#        [34.35973448],
#        [32.56110615],
#        [34.71711119],
#        [33.64162541],
#        [34.17685156],
#        [32.02084652],
#        [34.3882575 ],
#        [32.5309053 ],
#        [34.28926583],
#        [33.68189321],
#        [34.12819464],
#        [31.1383106 ],
#        [32.23560811],
#        [31.26918094],
#        [32.20205161],
#        [30.65845267],
#        [34.65503167],
#        [32.3966793 ],
#        [32.97720673],
#        [33.08794318],
#        [32.72217734],
#        [31.44703039],
#        [32.32621066],
#        [34.16342896],
#        [34.13490594],
#        [30.67858657],
#        [33.75236185],
# ...

# %% [markdown]
# Visualize the regression line

# %%
plt.scatter(x,y,color='green')
plt.plot(x_test,y_pred,color='red')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Final Check

# %%
check=pd.DataFrame(x_test,columns=['cities'])

# %%
check['selfcities']=y_test

# %%
check['othercities']=y_pred

# %%
check
# Out:
#      cities  selfcities  othercities
# 0      1623          23    32.007424
# 1       503          34    33.886588
# 2      1869           2    31.594679
# 3      2291          35    30.886637
# 4      1261           3    32.614797
# ..      ...         ...          ...
# 125     711          30    33.537600
# 126    1476          11    32.254064
# 127    2393          20    30.715499
# 128    1809         272    31.695348
# 129    1236           2    32.656742
#
# [130 rows x 3 columns]
